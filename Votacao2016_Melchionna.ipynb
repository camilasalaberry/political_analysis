# %%
import pandas as pd

# %%
votos = pd.read_csv("bweb_1t_RS.csv", sep=";", encoding="ISO-8859-1")

# %%
votos.head()
# Out:
#    dt_geracao h_geracao  cod_pleito  cod_eleicao  uf  cod_cargo desc_perg  \
# 0  04/10/2016  19:02:00         187          220  RS         11  Prefeito
# 1  04/10/2016  19:02:00         187          220  RS         11  Prefeito
# 2  04/10/2016  19:02:00         187          220  RS         11  Prefeito
# 3  04/10/2016  19:02:00         187          220  RS         11  Prefeito
# 4  04/10/2016  19:02:00         187          220  RS         11  Prefeito
#
#    zona_elei  secao_elei  nro_local_voto  ...  nro_votavel    nome_votavel  \
# 0          1           1            1422  ...           13       RAUL PONT
# 1          1           1            1422  ...           14        MAURICIO
# 2          1           1            1422  ...           15  SEBASTIÃO MELO
# 3          1           1            1422  ...           16    JULIO FLORES
# 4          1           1            1422  ...           96            NULO
#
# ...

# %%
votos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2001873 entries, 0 to 2001872
# Data columns (total 31 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   dt_geracao                object
#  1   h_geracao                 object
#  2   cod_pleito                int64
#  3   cod_eleicao               int64
#  4   uf                        object
#  5   cod_cargo                 int64
#  6   desc_perg                 object
#  7   zona_elei                 int64
#  8   secao_elei                int64
#  9   nro_local_voto            int64
#  10  nro_partido               int64
#  11  nome_partido              object
#  12  cod_munci                 int64
#  13  nome_munci                object
#  14  data_bu_rece              object
#  15  qtd_elei_aptos            int64
#  16  qtd_faltas_elei           int64
#  17  qtd_comparecimento        int64
#  18  cod_tp_elei               int64
#  19  cod_tp_urna               int64
# ...

# %%
selecao = (votos['nome_votavel'] == 'FERNANDA MELCHIONNA') & (votos['nome_munci'] == 'PORTO ALEGRE')

# %%
n2 = votos[selecao].shape[0]

n2
# Out:
# 2765

# %%
votos_fernanda = votos[selecao]

# %%
votos_fernanda.to_csv('votos_fernanda.csv', sep = ';')
